# %% [markdown]
# <a href="https://colab.research.google.com/github/Batwan01/2024-Challenge/blob/main/Park%20Jiwan/strange.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
# Google Drive를 마운트합니다.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import ParameterGrid
from sklearn.preprocessing import StandardScaler
from scipy import stats
import matplotlib.pyplot as plt
import json
import numpy as np
import random
import pandas as pd

# %%
train_csv_path = "/content/drive/MyDrive/Colab Notebooks/data/samsung/train.csv"

RANDOM_SEED = 18
torch.manual_seed(RANDOM_SEED)
torch.cuda.manual_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# 데이터 불러오기
train_data = pd.read_csv(train_csv_path)
X = train_data.iloc[:,1:-1].values  # 특성 데이터
y = train_data.iloc[:,-1].values    # 타겟 데이터

# 1. 특성 스케일링
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# # 2. 이상치 처리 (Z-Score를 사용하여 이상치 제거)
# z_scores = np.abs(stats.zscore(X_scaled))
# X_clean = X_scaled[(z_scores < 3).all(axis=1)]
# y_clean = y[(z_scores < 3).all(axis=1)]

# 3. 타겟 변수 변환 (로그 변환)
# y_log = np.log1p(y_clean)

# # 텐서로 변환
# X_tensor = torch.tensor(X_clean, dtype=torch.float32)
# y_tensor = torch.tensor(y_log, dtype=torch.float32).view(-1, 1)

#--------------------------------------------
#3. 타겟 변수 변환 (로그 변환)
y_log = np.log1p(y)

# 텐서로 변환
X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y_log, dtype=torch.float32).view(-1, 1)
#---------------------------------------------

# 데이터셋 분할 (Train/Validation Split)
X_train, X_val, y_train, y_val = train_test_split(X_tensor, y_tensor, test_size=0.2, random_state=RANDOM_SEED)

train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)

# MLP 모델 정의
class MLP(nn.Module):
    def __init__(self, input_size=11, hidden_sizes=[64, 128, 64], output_size=1):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_sizes[0])
        self.fc2 = nn.Linear(hidden_sizes[0], hidden_sizes[1])
        self.fc3 = nn.Linear(hidden_sizes[1], hidden_sizes[2])
        self.fc4 = nn.Linear(hidden_sizes[2], output_size)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
# # grid search 로 최적의 하이퍼파라미터 찾기
# param_grid = {
#     'hidden_sizes': [[64, 128, 64], [128, 256, 128], [32, 64, 32]],
#     'learning_rate': [0.01, 0.001, 0.0001],
#     'batch_size': [32, 64, 128],
# }

# def train_model(hidden_sizes, learning_rate, batch_size):
#     model = MLP(hidden_sizes=hidden_sizes)
#     model.cuda()
#     criterion = nn.MSELoss().cuda()
#     optimizer = optim.Adam(model.parameters(), lr=learning_rate)

#     train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#     val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

#     for epoch in range(100):
#         model.train()
#         for batch_X, batch_y in train_loader:
#             batch_X, batch_y = batch_X.cuda(), batch_y.cuda()
#             outputs = model(batch_X)
#             loss = criterion(outputs, batch_y)
#             optimizer.zero_grad()
#             loss.backward()
#             optimizer.step()

#     # 검증 성능 계산
#     model.eval()
#     val_loss = 0
#     with torch.no_grad():
#         for batch_X, batch_y in val_loader:
#             batch_X, batch_y = batch_X.cuda(), batch_y.cuda()
#             outputs = model(batch_X)
#             loss = criterion(outputs, batch_y)
#             val_loss += loss.item()

#     return val_loss / len(val_loader)

# best_params = None
# best_MSE = float('inf')
# for params in ParameterGrid(param_grid):
#     MSE = train_model(**params)
#     print(f"Testing parameters: {params} => MSE: {MSE:.4f}")
#     if MSE < best_MSE:
#         best_MSE = MSE
#         best_params = params

# print(f'\nBest parameters: {best_params} with a MSE of {best_MSE:.4f}')
# with open('3_layer_MLP_params.json', 'w') as json_file:
#     json.dump(best_params, json_file)
# Out:
# Testing parameters: {'batch_size': 32, 'hidden_sizes': [64, 128, 64], 'learning_rate': 0.01} => MSE: 0.0006
# Testing parameters: {'batch_size': 32, 'hidden_sizes': [64, 128, 64], 'learning_rate': 0.001} => MSE: 0.0007
# Testing parameters: {'batch_size': 32, 'hidden_sizes': [64, 128, 64], 'learning_rate': 0.0001} => MSE: 0.0007
# Testing parameters: {'batch_size': 32, 'hidden_sizes': [128, 256, 128], 'learning_rate': 0.01} => MSE: 0.0011
# Testing parameters: {'batch_size': 32, 'hidden_sizes': [128, 256, 128], 'learning_rate': 0.001} => MSE: 0.0007
# Testing parameters: {'batch_size': 32, 'hidden_sizes': [128, 256, 128], 'learning_rate': 0.0001} => MSE: 0.0007
# Testing parameters: {'batch_size': 32, 'hidden_sizes': [32, 64, 32], 'learning_rate': 0.01} => MSE: 0.0006
# Testing parameters: {'batch_size': 32, 'hidden_sizes': [32, 64, 32], 'learning_rate': 0.001} => MSE: 0.0006
# Testing parameters: {'batch_size': 32, 'hidden_sizes': [32, 64, 32], 'learning_rate': 0.0001} => MSE: 0.0007
# Testing parameters: {'batch_size': 64, 'hidden_sizes': [64, 128, 64], 'learning_rate': 0.01} => MSE: 0.0006
# Testing parameters: {'batch_size': 64, 'hidden_sizes': [64, 128, 64], 'learning_rate': 0.001} => MSE: 0.0009
# Testing parameters: {'batch_size': 64, 'hidden_sizes': [64, 128, 64], 'learning_rate': 0.0001} => MSE: 0.0007
# Testing parameters: {'batch_size': 64, 'hidden_sizes': [128, 256, 128], 'learning_rate': 0.01} => MSE: 0.0007
# Testing parameters: {'batch_size': 64, 'hidden_sizes': [128, 256, 128], 'learning_rate': 0.001} => MSE: 0.0007
# Testing parameters: {'batch_size': 64, 'hidden_sizes': [128, 256, 128], 'learning_rate': 0.0001} => MSE: 0.0008
# Testing parameters: {'batch_size': 64, 'hidden_sizes': [32, 64, 32], 'learning_rate': 0.01} => MSE: 0.0007
# Testing parameters: {'batch_size': 64, 'hidden_sizes': [32, 64, 32], 'learning_rate': 0.001} => MSE: 0.0007
# Testing parameters: {'batch_size': 64, 'hidden_sizes': [32, 64, 32], 'learning_rate': 0.0001} => MSE: 0.0007
# Testing parameters: {'batch_size': 128, 'hidden_sizes': [64, 128, 64], 'learning_rate': 0.01} => MSE: 0.0010
# Testing parameters: {'batch_size': 128, 'hidden_sizes': [64, 128, 64], 'learning_rate': 0.001} => MSE: 0.0009
# Testing parameters: {'batch_size': 128, 'hidden_sizes': [64, 128, 64], 'learning_rate': 0.0001} => MSE: 0.0008
# Testing parameters: {'batch_size': 128, 'hidden_sizes': [128, 256, 128], 'learning_rate': 0.01} => MSE: 0.0008
# Testing parameters: {'batch_size': 128, 'hidden_sizes': [128, 256, 128], 'learning_rate': 0.001} => MSE: 0.0008
# Testing parameters: {'batch_size': 128, 'hidden_sizes': [128, 256, 128], 'learning_rate': 0.0001} => MSE: 0.0009
# Testing parameters: {'batch_size': 128, 'hidden_sizes': [32, 64, 32], 'learning_rate': 0.01} => MSE: 0.0007
# Testing parameters: {'batch_size': 128, 'hidden_sizes': [32, 64, 32], 'learning_rate': 0.001} => MSE: 0.0007
# Testing parameters: {'batch_size': 128, 'hidden_sizes': [32, 64, 32], 'learning_rate': 0.0001} => MSE: 0.0008
#
# Best parameters: {'batch_size': 32, 'hidden_sizes': [32, 64, 32], 'learning_rate': 0.001} with a MSE of 0.0006

# %%
# best_hidden_sizes = best_params['hidden_sizes']
# best_learning_rate = best_params['learning_rate']
# best_batch_size = best_params['batch_size']

best_hidden_sizes = [32,64,32]
best_learning_rate = 0.001
best_batch_size = 32

model = MLP(hidden_sizes=best_hidden_sizes).cuda()
criterion = nn.MSELoss().cuda()
optimizer = optim.Adam(model.parameters(), lr=best_learning_rate)

train_loader = DataLoader(train_dataset, batch_size=best_batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=best_batch_size, shuffle=False)

train_losses = []
val_losses = []

for epoch in range(300):
    model.train()
    train_loss = 0.0
    for batch_X, batch_y in train_loader:
        batch_X, batch_y = batch_X.cuda(), batch_y.cuda()
        outputs = model(batch_X)

        # 로그 값을 풀어준 후 MSE 계산
        outputs_exp = torch.exp(outputs)
        batch_y_exp = torch.exp(batch_y)
        loss = criterion(outputs, batch_y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    train_loss = train_loss / len(train_loader)
    train_losses.append(train_loss)

    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for batch_X, batch_y in val_loader:
            batch_X, batch_y = batch_X.cuda(), batch_y.cuda()
            outputs = model(batch_X)

            # 로그 값을 풀어준 후 MSE 계산
            outputs_exp = torch.exp(outputs)
            batch_y_exp = torch.exp(batch_y)
            loss = criterion(outputs_exp, batch_y_exp)

            val_loss += loss.item()

    val_loss = val_loss / len(val_loader)
    val_losses.append(val_loss)

    print(f'Epoch {epoch+1}/300, Train Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}')
# Out:
# Epoch 1/300, Train Loss: 0.7356, Validation Loss: 6.7840
# Epoch 2/300, Train Loss: 0.0009, Validation Loss: 6.3170
# Epoch 3/300, Train Loss: 0.0009, Validation Loss: 5.4828
# Epoch 4/300, Train Loss: 0.0008, Validation Loss: 5.1524
# Epoch 5/300, Train Loss: 0.0007, Validation Loss: 6.6081
# Epoch 6/300, Train Loss: 0.0007, Validation Loss: 4.3423
# Epoch 7/300, Train Loss: 0.0007, Validation Loss: 4.9951
# Epoch 8/300, Train Loss: 0.0007, Validation Loss: 5.8617
# Epoch 9/300, Train Loss: 0.0007, Validation Loss: 4.7050
# Epoch 10/300, Train Loss: 0.0006, Validation Loss: 3.9557
# Epoch 11/300, Train Loss: 0.0006, Validation Loss: 3.5653
# Epoch 12/300, Train Loss: 0.0006, Validation Loss: 3.8650
# Epoch 13/300, Train Loss: 0.0006, Validation Loss: 3.9061
# Epoch 14/300, Train Loss: 0.0006, Validation Loss: 4.8822
# Epoch 15/300, Train Loss: 0.0006, Validation Loss: 3.5508
# Epoch 16/300, Train Loss: 0.0006, Validation Loss: 4.6505
# Epoch 17/300, Train Loss: 0.0007, Validation Loss: 3.7546
# Epoch 18/300, Train Loss: 0.0006, Validation Loss: 3.3984
# Epoch 19/300, Train Loss: 0.0006, Validation Loss: 6.5797
# Epoch 20/300, Train Loss: 0.0006, Validation Loss: 4.6513
# Epoch 21/300, Train Loss: 0.0006, Validation Loss: 7.7686
# Epoch 22/300, Train Loss: 0.0006, Validation Loss: 3.8901
# Epoch 23/300, Train Loss: 0.0006, Validation Loss: 13.5298
# Epoch 24/300, Train Loss: 0.0006, Validation Loss: 3.9811
# Epoch 25/300, Train Loss: 0.0006, Validation Loss: 3.4740
# Epoch 26/300, Train Loss: 0.0006, Validation Loss: 3.4488
# Epoch 27/300, Train Loss: 0.0006, Validation Loss: 3.5024
# Epoch 28/300, Train Loss: 0.0006, Validation Loss: 3.7406
# Epoch 29/300, Train Loss: 0.0006, Validation Loss: 3.4378
# Epoch 30/300, Train Loss: 0.0006, Validation Loss: 3.7696
# Epoch 31/300, Train Loss: 0.0006, Validation Loss: 3.3295
# Epoch 32/300, Train Loss: 0.0006, Validation Loss: 6.5100
# Epoch 33/300, Train Loss: 0.0006, Validation Loss: 4.1600
# Epoch 34/300, Train Loss: 0.0006, Validation Loss: 3.6508
# Epoch 35/300, Train Loss: 0.0006, Validation Loss: 3.8228
# Epoch 36/300, Train Loss: 0.0006, Validation Loss: 4.7885
# Epoch 37/300, Train Loss: 0.0006, Validation Loss: 3.5534
# Epoch 38/300, Train Loss: 0.0006, Validation Loss: 3.5181
# Epoch 39/300, Train Loss: 0.0006, Validation Loss: 4.2183
# Epoch 40/300, Train Loss: 0.0006, Validation Loss: 5.3213
# Epoch 41/300, Train Loss: 0.0006, Validation Loss: 3.8422
# Epoch 42/300, Train Loss: 0.0006, Validation Loss: 3.4568
# Epoch 43/300, Train Loss: 0.0006, Validation Loss: 5.9021
# Epoch 44/300, Train Loss: 0.0006, Validation Loss: 3.3065
# Epoch 45/300, Train Loss: 0.0006, Validation Loss: 8.6241
# Epoch 46/300, Train Loss: 0.0006, Validation Loss: 3.2831
# Epoch 47/300, Train Loss: 0.0006, Validation Loss: 3.6313
# Epoch 48/300, Train Loss: 0.0006, Validation Loss: 3.3653
# Epoch 49/300, Train Loss: 0.0006, Validation Loss: 3.3565
# Epoch 50/300, Train Loss: 0.0006, Validation Loss: 4.3152
# Epoch 51/300, Train Loss: 0.0006, Validation Loss: 4.8021
# Epoch 52/300, Train Loss: 0.0006, Validation Loss: 4.0341
# Epoch 53/300, Train Loss: 0.0006, Validation Loss: 6.2304
# Epoch 54/300, Train Loss: 0.0005, Validation Loss: 3.5371
# Epoch 55/300, Train Loss: 0.0006, Validation Loss: 3.5607
# Epoch 56/300, Train Loss: 0.0006, Validation Loss: 3.4966
# Epoch 57/300, Train Loss: 0.0006, Validation Loss: 4.1925
# Epoch 58/300, Train Loss: 0.0006, Validation Loss: 3.2901
# Epoch 59/300, Train Loss: 0.0006, Validation Loss: 3.2733
# Epoch 60/300, Train Loss: 0.0006, Validation Loss: 5.4442
# Epoch 61/300, Train Loss: 0.0006, Validation Loss: 4.4670
# Epoch 62/300, Train Loss: 0.0006, Validation Loss: 3.3082
# Epoch 63/300, Train Loss: 0.0006, Validation Loss: 3.7977
# Epoch 64/300, Train Loss: 0.0006, Validation Loss: 3.2949
# Epoch 65/300, Train Loss: 0.0006, Validation Loss: 4.1960
# Epoch 66/300, Train Loss: 0.0006, Validation Loss: 3.6874
# Epoch 67/300, Train Loss: 0.0005, Validation Loss: 3.6075
# Epoch 68/300, Train Loss: 0.0006, Validation Loss: 3.4770
# Epoch 69/300, Train Loss: 0.0006, Validation Loss: 5.4586
# Epoch 70/300, Train Loss: 0.0006, Validation Loss: 5.8257
# Epoch 71/300, Train Loss: 0.0006, Validation Loss: 3.3627
# Epoch 72/300, Train Loss: 0.0006, Validation Loss: 4.0732
# Epoch 73/300, Train Loss: 0.0006, Validation Loss: 5.6090
# Epoch 74/300, Train Loss: 0.0005, Validation Loss: 3.5266
# Epoch 75/300, Train Loss: 0.0005, Validation Loss: 3.6186
# Epoch 76/300, Train Loss: 0.0006, Validation Loss: 3.6113
# Epoch 77/300, Train Loss: 0.0005, Validation Loss: 3.2951
# Epoch 78/300, Train Loss: 0.0006, Validation Loss: 3.5779
# Epoch 79/300, Train Loss: 0.0005, Validation Loss: 4.1304
# Epoch 80/300, Train Loss: 0.0005, Validation Loss: 3.8334
# Epoch 81/300, Train Loss: 0.0006, Validation Loss: 3.3028
# Epoch 82/300, Train Loss: 0.0006, Validation Loss: 4.1196
# Epoch 83/300, Train Loss: 0.0006, Validation Loss: 4.4471
# Epoch 84/300, Train Loss: 0.0005, Validation Loss: 3.5893
# Epoch 85/300, Train Loss: 0.0006, Validation Loss: 3.2496
# Epoch 86/300, Train Loss: 0.0005, Validation Loss: 3.3416
# Epoch 87/300, Train Loss: 0.0005, Validation Loss: 3.2928
# Epoch 88/300, Train Loss: 0.0005, Validation Loss: 3.3314
# Epoch 89/300, Train Loss: 0.0005, Validation Loss: 3.6259
# Epoch 90/300, Train Loss: 0.0005, Validation Loss: 3.4348
# Epoch 91/300, Train Loss: 0.0005, Validation Loss: 5.4315
# Epoch 92/300, Train Loss: 0.0006, Validation Loss: 4.8384
# Epoch 93/300, Train Loss: 0.0006, Validation Loss: 3.5712
# Epoch 94/300, Train Loss: 0.0005, Validation Loss: 4.1982
# Epoch 95/300, Train Loss: 0.0005, Validation Loss: 3.2999
# Epoch 96/300, Train Loss: 0.0005, Validation Loss: 4.4787
# Epoch 97/300, Train Loss: 0.0006, Validation Loss: 3.7889
# Epoch 98/300, Train Loss: 0.0005, Validation Loss: 4.5766
# Epoch 99/300, Train Loss: 0.0006, Validation Loss: 3.4190
# Epoch 100/300, Train Loss: 0.0006, Validation Loss: 4.2080
# Epoch 101/300, Train Loss: 0.0006, Validation Loss: 4.4049
# Epoch 102/300, Train Loss: 0.0006, Validation Loss: 3.3506
# Epoch 103/300, Train Loss: 0.0005, Validation Loss: 4.0871
# Epoch 104/300, Train Loss: 0.0005, Validation Loss: 3.3997
# Epoch 105/300, Train Loss: 0.0005, Validation Loss: 5.1171
# Epoch 106/300, Train Loss: 0.0005, Validation Loss: 11.7350
# Epoch 107/300, Train Loss: 0.0005, Validation Loss: 3.9890
# Epoch 108/300, Train Loss: 0.0005, Validation Loss: 3.7445
# Epoch 109/300, Train Loss: 0.0005, Validation Loss: 3.5886
# Epoch 110/300, Train Loss: 0.0005, Validation Loss: 3.3239
# Epoch 111/300, Train Loss: 0.0006, Validation Loss: 3.4730
# Epoch 112/300, Train Loss: 0.0005, Validation Loss: 3.8079
# Epoch 113/300, Train Loss: 0.0006, Validation Loss: 3.2402
# Epoch 114/300, Train Loss: 0.0005, Validation Loss: 3.6145
# Epoch 115/300, Train Loss: 0.0005, Validation Loss: 4.4334
# Epoch 116/300, Train Loss: 0.0005, Validation Loss: 4.6519
# Epoch 117/300, Train Loss: 0.0005, Validation Loss: 3.2383
# Epoch 118/300, Train Loss: 0.0005, Validation Loss: 3.8186
# Epoch 119/300, Train Loss: 0.0005, Validation Loss: 3.3461
# Epoch 120/300, Train Loss: 0.0005, Validation Loss: 3.2360
# Epoch 121/300, Train Loss: 0.0005, Validation Loss: 3.6059
# Epoch 122/300, Train Loss: 0.0005, Validation Loss: 3.6193
# Epoch 123/300, Train Loss: 0.0005, Validation Loss: 4.0250
# Epoch 124/300, Train Loss: 0.0005, Validation Loss: 3.3511
# Epoch 125/300, Train Loss: 0.0005, Validation Loss: 3.6741
# Epoch 126/300, Train Loss: 0.0005, Validation Loss: 3.6496
# Epoch 127/300, Train Loss: 0.0005, Validation Loss: 5.7622
# Epoch 128/300, Train Loss: 0.0006, Validation Loss: 5.3016
# Epoch 129/300, Train Loss: 0.0005, Validation Loss: 5.3018
# Epoch 130/300, Train Loss: 0.0006, Validation Loss: 3.2726
# Epoch 131/300, Train Loss: 0.0005, Validation Loss: 3.9331
# Epoch 132/300, Train Loss: 0.0005, Validation Loss: 3.7766
# Epoch 133/300, Train Loss: 0.0005, Validation Loss: 3.2495
# Epoch 134/300, Train Loss: 0.0005, Validation Loss: 3.4221
# Epoch 135/300, Train Loss: 0.0005, Validation Loss: 3.3139
# Epoch 136/300, Train Loss: 0.0005, Validation Loss: 3.6499
# Epoch 137/300, Train Loss: 0.0005, Validation Loss: 3.2366
# Epoch 138/300, Train Loss: 0.0005, Validation Loss: 5.6780
# Epoch 139/300, Train Loss: 0.0005, Validation Loss: 3.2417
# Epoch 140/300, Train Loss: 0.0005, Validation Loss: 3.2721
# Epoch 141/300, Train Loss: 0.0005, Validation Loss: 6.9739
# Epoch 142/300, Train Loss: 0.0005, Validation Loss: 3.2215
# Epoch 143/300, Train Loss: 0.0005, Validation Loss: 3.3417
# Epoch 144/300, Train Loss: 0.0005, Validation Loss: 3.5256
# Epoch 145/300, Train Loss: 0.0005, Validation Loss: 4.1380
# Epoch 146/300, Train Loss: 0.0005, Validation Loss: 3.2816
# Epoch 147/300, Train Loss: 0.0005, Validation Loss: 3.4348
# Epoch 148/300, Train Loss: 0.0005, Validation Loss: 3.2173
# Epoch 149/300, Train Loss: 0.0005, Validation Loss: 3.2357
# Epoch 150/300, Train Loss: 0.0005, Validation Loss: 8.5371
# Epoch 151/300, Train Loss: 0.0006, Validation Loss: 3.2707
# Epoch 152/300, Train Loss: 0.0005, Validation Loss: 3.2807
# Epoch 153/300, Train Loss: 0.0005, Validation Loss: 3.3614
# Epoch 154/300, Train Loss: 0.0005, Validation Loss: 3.2577
# Epoch 155/300, Train Loss: 0.0005, Validation Loss: 3.2242
# Epoch 156/300, Train Loss: 0.0005, Validation Loss: 3.3871
# Epoch 157/300, Train Loss: 0.0005, Validation Loss: 3.2355
# Epoch 158/300, Train Loss: 0.0005, Validation Loss: 4.4604
# Epoch 159/300, Train Loss: 0.0005, Validation Loss: 3.2319
# Epoch 160/300, Train Loss: 0.0005, Validation Loss: 3.8944
# Epoch 161/300, Train Loss: 0.0005, Validation Loss: 3.3251
# Epoch 162/300, Train Loss: 0.0005, Validation Loss: 3.2812
# Epoch 163/300, Train Loss: 0.0005, Validation Loss: 3.2444
# Epoch 164/300, Train Loss: 0.0005, Validation Loss: 3.5860
# Epoch 165/300, Train Loss: 0.0005, Validation Loss: 3.9829
# Epoch 166/300, Train Loss: 0.0005, Validation Loss: 3.6638
# Epoch 167/300, Train Loss: 0.0005, Validation Loss: 3.3502
# Epoch 168/300, Train Loss: 0.0005, Validation Loss: 6.9166
# Epoch 169/300, Train Loss: 0.0005, Validation Loss: 3.2200
# Epoch 170/300, Train Loss: 0.0005, Validation Loss: 4.0590
# Epoch 171/300, Train Loss: 0.0005, Validation Loss: 3.7542
# Epoch 172/300, Train Loss: 0.0005, Validation Loss: 3.6236
# Epoch 173/300, Train Loss: 0.0005, Validation Loss: 3.2175
# Epoch 174/300, Train Loss: 0.0005, Validation Loss: 3.2900
# Epoch 175/300, Train Loss: 0.0005, Validation Loss: 3.8095
# Epoch 176/300, Train Loss: 0.0005, Validation Loss: 3.3794
# Epoch 177/300, Train Loss: 0.0005, Validation Loss: 3.9607
# Epoch 178/300, Train Loss: 0.0005, Validation Loss: 3.2376
# Epoch 179/300, Train Loss: 0.0005, Validation Loss: 3.2154
# Epoch 180/300, Train Loss: 0.0005, Validation Loss: 3.6202
# Epoch 181/300, Train Loss: 0.0005, Validation Loss: 3.6057
# Epoch 182/300, Train Loss: 0.0005, Validation Loss: 4.0431
# Epoch 183/300, Train Loss: 0.0005, Validation Loss: 5.2898
# Epoch 184/300, Train Loss: 0.0005, Validation Loss: 3.4783
# Epoch 185/300, Train Loss: 0.0005, Validation Loss: 3.5346
# Epoch 186/300, Train Loss: 0.0005, Validation Loss: 3.4792
# Epoch 187/300, Train Loss: 0.0005, Validation Loss: 3.6292
# Epoch 188/300, Train Loss: 0.0005, Validation Loss: 3.7687
# Epoch 189/300, Train Loss: 0.0005, Validation Loss: 3.7394
# Epoch 190/300, Train Loss: 0.0005, Validation Loss: 3.2062
# Epoch 191/300, Train Loss: 0.0005, Validation Loss: 3.2117
# Epoch 192/300, Train Loss: 0.0005, Validation Loss: 5.1583
# Epoch 193/300, Train Loss: 0.0005, Validation Loss: 4.2770
# Epoch 194/300, Train Loss: 0.0005, Validation Loss: 4.3241
# Epoch 195/300, Train Loss: 0.0005, Validation Loss: 3.2615
# Epoch 196/300, Train Loss: 0.0005, Validation Loss: 3.7979
# Epoch 197/300, Train Loss: 0.0005, Validation Loss: 3.4419
# Epoch 198/300, Train Loss: 0.0005, Validation Loss: 3.6392
# Epoch 199/300, Train Loss: 0.0005, Validation Loss: 3.2745
# Epoch 200/300, Train Loss: 0.0005, Validation Loss: 3.2259
# Epoch 201/300, Train Loss: 0.0005, Validation Loss: 3.2480
# Epoch 202/300, Train Loss: 0.0005, Validation Loss: 3.7023
# Epoch 203/300, Train Loss: 0.0005, Validation Loss: 3.6936
# Epoch 204/300, Train Loss: 0.0005, Validation Loss: 3.4408
# Epoch 205/300, Train Loss: 0.0005, Validation Loss: 3.2831
# Epoch 206/300, Train Loss: 0.0005, Validation Loss: 5.3391
# Epoch 207/300, Train Loss: 0.0005, Validation Loss: 3.2817
# Epoch 208/300, Train Loss: 0.0005, Validation Loss: 3.2201
# Epoch 209/300, Train Loss: 0.0005, Validation Loss: 3.2588
# Epoch 210/300, Train Loss: 0.0005, Validation Loss: 3.3205
# Epoch 211/300, Train Loss: 0.0005, Validation Loss: 3.3990
# Epoch 212/300, Train Loss: 0.0005, Validation Loss: 3.4889
# Epoch 213/300, Train Loss: 0.0005, Validation Loss: 3.6853
# Epoch 214/300, Train Loss: 0.0005, Validation Loss: 3.2298
# Epoch 215/300, Train Loss: 0.0005, Validation Loss: 3.4191
# Epoch 216/300, Train Loss: 0.0005, Validation Loss: 3.5749
# Epoch 217/300, Train Loss: 0.0005, Validation Loss: 3.3099
# Epoch 218/300, Train Loss: 0.0005, Validation Loss: 3.2190
# Epoch 219/300, Train Loss: 0.0005, Validation Loss: 3.2477
# Epoch 220/300, Train Loss: 0.0005, Validation Loss: 3.2455
# Epoch 221/300, Train Loss: 0.0005, Validation Loss: 4.2356
# Epoch 222/300, Train Loss: 0.0005, Validation Loss: 3.4017
# Epoch 223/300, Train Loss: 0.0005, Validation Loss: 4.1552
# Epoch 224/300, Train Loss: 0.0005, Validation Loss: 3.9493
# Epoch 225/300, Train Loss: 0.0005, Validation Loss: 3.8786
# Epoch 226/300, Train Loss: 0.0005, Validation Loss: 3.5410
# Epoch 227/300, Train Loss: 0.0005, Validation Loss: 3.5461
# Epoch 228/300, Train Loss: 0.0005, Validation Loss: 3.2573
# Epoch 229/300, Train Loss: 0.0005, Validation Loss: 3.3591
# Epoch 230/300, Train Loss: 0.0005, Validation Loss: 3.3225
# Epoch 231/300, Train Loss: 0.0005, Validation Loss: 3.6257
# Epoch 232/300, Train Loss: 0.0005, Validation Loss: 4.2757
# Epoch 233/300, Train Loss: 0.0005, Validation Loss: 4.7776
# Epoch 234/300, Train Loss: 0.0005, Validation Loss: 8.1402
# Epoch 235/300, Train Loss: 0.0005, Validation Loss: 3.4172
# Epoch 236/300, Train Loss: 0.0005, Validation Loss: 3.2632
# Epoch 237/300, Train Loss: 0.0005, Validation Loss: 3.3784
# Epoch 238/300, Train Loss: 0.0005, Validation Loss: 3.7147
# Epoch 239/300, Train Loss: 0.0005, Validation Loss: 3.5567
# Epoch 240/300, Train Loss: 0.0005, Validation Loss: 3.2051
# Epoch 241/300, Train Loss: 0.0005, Validation Loss: 4.6781
# Epoch 242/300, Train Loss: 0.0005, Validation Loss: 3.2225
# Epoch 243/300, Train Loss: 0.0005, Validation Loss: 3.2393
# Epoch 244/300, Train Loss: 0.0005, Validation Loss: 4.2758
# Epoch 245/300, Train Loss: 0.0005, Validation Loss: 3.4327
# Epoch 246/300, Train Loss: 0.0005, Validation Loss: 3.2140
# Epoch 247/300, Train Loss: 0.0005, Validation Loss: 3.4389
# Epoch 248/300, Train Loss: 0.0005, Validation Loss: 4.0543
# Epoch 249/300, Train Loss: 0.0005, Validation Loss: 3.4460
# Epoch 250/300, Train Loss: 0.0005, Validation Loss: 3.5930
# Epoch 251/300, Train Loss: 0.0005, Validation Loss: 5.7652
# Epoch 252/300, Train Loss: 0.0005, Validation Loss: 3.5468
# Epoch 253/300, Train Loss: 0.0005, Validation Loss: 3.6449
# Epoch 254/300, Train Loss: 0.0005, Validation Loss: 4.4173
# Epoch 255/300, Train Loss: 0.0005, Validation Loss: 3.2569
# Epoch 256/300, Train Loss: 0.0005, Validation Loss: 3.6039
# Epoch 257/300, Train Loss: 0.0005, Validation Loss: 3.5688
# Epoch 258/300, Train Loss: 0.0005, Validation Loss: 3.2074
# Epoch 259/300, Train Loss: 0.0005, Validation Loss: 4.6447
# Epoch 260/300, Train Loss: 0.0005, Validation Loss: 4.8640
# Epoch 261/300, Train Loss: 0.0005, Validation Loss: 3.4225
# Epoch 262/300, Train Loss: 0.0005, Validation Loss: 3.2802
# Epoch 263/300, Train Loss: 0.0005, Validation Loss: 3.3009
# Epoch 264/300, Train Loss: 0.0005, Validation Loss: 3.2183
# Epoch 265/300, Train Loss: 0.0005, Validation Loss: 4.2330
# Epoch 266/300, Train Loss: 0.0005, Validation Loss: 4.8414
# Epoch 267/300, Train Loss: 0.0005, Validation Loss: 3.2045
# Epoch 268/300, Train Loss: 0.0005, Validation Loss: 3.3423
# Epoch 269/300, Train Loss: 0.0005, Validation Loss: 3.2054
# Epoch 270/300, Train Loss: 0.0005, Validation Loss: 3.8374
# Epoch 271/300, Train Loss: 0.0005, Validation Loss: 3.2149
# Epoch 272/300, Train Loss: 0.0005, Validation Loss: 3.2366
# Epoch 273/300, Train Loss: 0.0005, Validation Loss: 4.6944
# Epoch 274/300, Train Loss: 0.0005, Validation Loss: 3.4603
# Epoch 275/300, Train Loss: 0.0005, Validation Loss: 4.2913
# Epoch 276/300, Train Loss: 0.0005, Validation Loss: 3.2932
# Epoch 277/300, Train Loss: 0.0005, Validation Loss: 3.2035
# Epoch 278/300, Train Loss: 0.0005, Validation Loss: 3.5461
# Epoch 279/300, Train Loss: 0.0005, Validation Loss: 3.2645
# Epoch 280/300, Train Loss: 0.0005, Validation Loss: 3.2980
# Epoch 281/300, Train Loss: 0.0005, Validation Loss: 3.2962
# Epoch 282/300, Train Loss: 0.0005, Validation Loss: 3.5236
# Epoch 283/300, Train Loss: 0.0005, Validation Loss: 4.4017
# Epoch 284/300, Train Loss: 0.0005, Validation Loss: 3.2235
# Epoch 285/300, Train Loss: 0.0005, Validation Loss: 3.1998
# Epoch 286/300, Train Loss: 0.0005, Validation Loss: 3.2534
# Epoch 287/300, Train Loss: 0.0005, Validation Loss: 4.6032
# Epoch 288/300, Train Loss: 0.0005, Validation Loss: 3.1973
# Epoch 289/300, Train Loss: 0.0005, Validation Loss: 3.4615
# Epoch 290/300, Train Loss: 0.0005, Validation Loss: 3.3350
# Epoch 291/300, Train Loss: 0.0005, Validation Loss: 3.3538
# Epoch 292/300, Train Loss: 0.0005, Validation Loss: 3.7492
# Epoch 293/300, Train Loss: 0.0005, Validation Loss: 3.9213
# Epoch 294/300, Train Loss: 0.0005, Validation Loss: 3.2738
# Epoch 295/300, Train Loss: 0.0005, Validation Loss: 4.6667
# Epoch 296/300, Train Loss: 0.0005, Validation Loss: 3.2310
# Epoch 297/300, Train Loss: 0.0005, Validation Loss: 3.3645
# Epoch 298/300, Train Loss: 0.0005, Validation Loss: 4.2718
# Epoch 299/300, Train Loss: 0.0005, Validation Loss: 3.9911
# Epoch 300/300, Train Loss: 0.0005, Validation Loss: 4.5856

# %%
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train and Validation Loss')
plt.ylim(0, 10)  # y축 범위를 0에서 10으로 제한
plt.legend()
plt.grid(True)
plt.show()

# %%
import os

test_csv_path = "/content/drive/MyDrive/Colab Notebooks/data/samsung/test.csv"

X_test = pd.read_csv(test_csv_path).iloc[:,1:].values

# 테스트 데이터에도 동일한 스케일링 적용
X_test_scaled = scaler.transform(X_test)
X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32)

test_dataset = TensorDataset(X_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=best_batch_size, shuffle=False)

model_save_path = "model_checkpoint_epoch500.pth"
torch.save(model.state_dict(), model_save_path)

model.eval()
test_pred = []
with torch.no_grad():
    for batch in test_loader:
        batch_X = batch[0].cuda()
        outputs = model(batch_X)
        test_pred.extend(outputs.cpu().numpy())  # 예측값을 CPU로 이동하여 리스트에 추가

test_pred = np.array(test_pred).flatten()
test_pred_original_scale = np.expm1(test_pred)
# 상위 10% 임계값 계산
threshold = np.percentile(test_pred_original_scale, 90)
top_10_percent_mask = test_pred_original_scale >= threshold
from datetime import datetime

# 현재 시간을 가져와서 문자열로 변환합니다.
current_time = datetime.now().strftime("%Y%m%d_%H:%M")

# 파일 이름에 현재 시간을 포함시킵니다.
submission_csv_path = f'/content/drive/MyDrive/Colab Notebooks/data/samsung/result/MLP_3_layers_{current_time}.csv'

# 예측 결과를 저장하기 전에 디렉토리가 존재하는지 확인
if not os.path.exists(os.path.dirname(submission_csv_path)):
    os.makedirs(os.path.dirname(submission_csv_path))

# 빈 데이터프레임 생성 (또는 제출 형식에 맞게 생성)
submission_df = pd.DataFrame()
submission_df['y'] = test_pred_original_scale  # 예측 결과를 y 컬럼에 추가

# 지정된 경로에 CSV 파일로 저장
submission_df.to_csv(submission_csv_path, index=False)

# %%
# 로그 스케일을 원래 값으로 변환
test_pred_original_scale_exp = np.exp(test_pred_original_scale)

# 상위 10% 임계값 계산
threshold = np.percentile(test_pred_original_scale, 90)
top_10_percent_mask = test_pred_original_scale >= threshold

# 결과 출력
print(f"Top 10% threshold: {threshold:.4f}")
print(f"Number of samples in top 10%: {sum(top_10_percent_mask)}")
# Out:
# Top 10% threshold: 34260.8730
# Number of samples in top 10%: 499
# <ipython-input-15-695b8bbbd9c6>:2: RuntimeWarning: overflow encountered in exp
#   test_pred_original_scale_exp = np.exp(test_pred_original_scale)
