# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import json
import numpy as np
import random
import pandas as pd

from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import ParameterGrid
from google.colab import drive

drive.mount('/content/drive')

# 재현 가능성을 위한 시드 고정
RANDOM_SEED = 18
torch.manual_seed(RANDOM_SEED)
torch.cuda.manual_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# Dataloader 시드 고정 (아직 사용 x)
'''
generator = torch.Generator()
generator.manual_seed(RANDOM_SEED)

def worker_init_fn(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

# DataLoader(worker_init_fn=worker_init_fn)
'''

# 데이터 경로 설정
train_csv_path = "/content/drive/MyDrive/train.csv"
test_csv_path = "/content/drive/MyDrive/test.csv"
submission_csv_path = '/content/drive/MyDrive/sample_submission.csv'
# Out:
# Mounted at /content/drive

# %%
from sklearn.preprocessing import StandardScaler

# %%
# MLP - 은닉층 5개
'''
Grid Search 하이퍼파라미터 범위

[Epoch 100 기준]
param_grid = {
    'hidden_sizes': [[64, 128, 128, 64, 32], [128, 256, 256, 128, 64], [32, 64, 64, 32, 16]],
    'learning_rate': [0.01, 0.001],
    'batch_size': [32, 64, 128],
}
'''
# 현재 최고성능 모델 하이퍼파라미터(GS) : {"batch_size": 32, "hidden_sizes": [32, 64, 64, 32, 16], "learning_rate": 0.001}
# Epoch : 93
# Top 10% threshold: 92.9191
# 제출 성능 : 0.736
class MLP5Hidden(nn.Module):
    def __init__(self, input_size=11, hidden_sizes=[32, 64, 64, 32, 16], output_size=1):
        super(MLP5Hidden, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_sizes[0])
        self.fc2 = nn.Linear(hidden_sizes[0], hidden_sizes[1])
        self.fc3 = nn.Linear(hidden_sizes[1], hidden_sizes[2])
        self.fc4 = nn.Linear(hidden_sizes[2], hidden_sizes[3])
        self.fc5 = nn.Linear(hidden_sizes[3], hidden_sizes[4])
        self.fc6 = nn.Linear(hidden_sizes[4], output_size)
        self.prelu = nn.PReLU()

    def forward(self, x):
        x = self.prelu(self.fc1(x))
        x = self.prelu(self.fc2(x))
        x = self.prelu(self.fc3(x))
        x = self.prelu(self.fc4(x))
        x = self.prelu(self.fc5(x))
        x = self.fc6(x)
        return x

# %%
train_data = pd.read_csv(train_csv_path)
X = train_data.iloc[:,1:-1]  # 특성 데이터
y = train_data.iloc[:,-1]   # 타겟 데이터
test_csv_path = "/content/drive/MyDrive/test.csv"
X_test = pd.read_csv(test_csv_path).iloc[:,1:]
X_concat = pd.concat([X,X_test])
X_concat = X_concat.values

# %%
X.describe()
# Out:
#                 x_0           x_1           x_2           x_3           x_4  \
# count  40118.000000  40118.000000  40118.000000  40118.000000  40118.000000
# mean       1.047842     -2.204742      1.201854      0.868693     -0.277682
# std        0.040025      0.309915      0.036752      0.048606      0.039428
# min        0.907816     -2.548461      1.056123      0.741617     -0.581258
# 25%        1.028898     -2.427270      1.176222      0.832690     -0.285265
# 50%        1.054757     -2.330303      1.212876      0.871334     -0.265732
# 75%        1.076332     -2.061368      1.231058      0.908141     -0.255766
# max        1.112987     -0.971386      1.253528      0.964632     -0.243130
#
#                 x_5           x_6           x_7           x_8           x_9  \
# count  40118.000000  40118.000000  40118.000000  40118.000000  40118.000000
# mean      -1.775907      0.488336     -0.168241      0.653337      0.288575
# std        0.043249      0.015579      0.037058      0.037680      0.042907
# min       -1.817216      0.463784     -0.231485      0.574932      0.222945
# 25%       -1.805732      0.474365     -0.196759      0.622813      0.252706
# 50%       -1.790160      0.488100     -0.174313      0.663973      0.281562
# 75%       -1.760420      0.500362     -0.145610      0.688103      0.317799
# max       -1.545138      0.585086     -0.055259      0.700005      0.428381
#
#                x_10
# count  40118.000000
# mean       0.078679
# std        0.023325
# min       -0.060792
# 25%        0.074605
# 50%        0.086375
# 75%        0.093821
# max        0.097734

# %%
# 1. 특성 스케일링
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_concat)
X = X_scaled[:40118]
X_test = X_scaled[40118:]

# # 2. 이상치 처리 (Z-Score를 사용하여 이상치 제거)
# z_scores = np.abs(stats.zscore(X_scaled))
# X_clean = X_scaled[(z_scores < 3).all(axis=1)]
# y_clean = y[(z_scores < 3).all(axis=1)]

# 3. 타겟 변수 변환 (로그 변환)
# y_log = np.log1p(y_clean)

# # 텐서로 변환
# X_tensor = torch.tensor(X_clean, dtype=torch.float32)
# y_tensor = torch.tensor(y_log, dtype=torch.float32).view(-1, 1)

#--------------------------------------------
#3. 타겟 변수 변환 (로그 변환)
y_log = np.log1p(y)

# 텐서로 변환
X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y_log, dtype=torch.float32).view(-1, 1)
#---------------------------------------------

# 데이터셋 분할 (Train/Validation Split)
X_train, X_val, y_train, y_val = train_test_split(X_tensor, y_tensor, test_size=0.2, random_state=RANDOM_SEED)

train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)

# %%
# best_hidden_sizes = best_params['hidden_sizes']
# best_learning_rate = best_params['learning_rate']
# best_batch_size = best_params['batch_size']

best_hidden_sizes = [32,64,32]
best_learning_rate = 0.001
best_batch_size = 32

model = MLP5Hidden().cuda()
criterion = nn.MSELoss().cuda()
optimizer = optim.Adam(model.parameters(), lr=best_learning_rate)

train_loader = DataLoader(train_dataset, batch_size=best_batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=best_batch_size, shuffle=False)

train_losses = []
val_losses = []

for epoch in range(100):
    model.train()
    train_loss = 0.0
    for batch_X, batch_y in train_loader:
        batch_X, batch_y = batch_X.cuda(), batch_y.cuda()
        outputs = model(batch_X)

        # 로그 값을 풀어준 후 MSE 계산
        outputs_exp = torch.exp(outputs)
        batch_y_exp = torch.exp(batch_y)
        loss = criterion(outputs_exp, batch_y_exp)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    train_loss = train_loss / len(train_loader)
    train_losses.append(train_loss)

    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for batch_X, batch_y in val_loader:
            batch_X, batch_y = batch_X.cuda(), batch_y.cuda()
            outputs = model(batch_X)

            # 로그 값을 풀어준 후 MSE 계산
            outputs_exp = torch.exp(outputs)
            batch_y_exp = torch.exp(batch_y)
            loss = criterion(outputs_exp, batch_y_exp)

            val_loss += loss.item()

    val_loss = val_loss / len(val_loader)
    val_losses.append(val_loss)

    print(f'Epoch {epoch+1}/300, Train Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}')
# Out:
# Epoch 1/300, Train Loss: 646.9441, Validation Loss: 65.1769
# Epoch 2/300, Train Loss: 37.4009, Validation Loss: 19.5240
# Epoch 3/300, Train Loss: 14.9734, Validation Loss: 14.7700
# Epoch 4/300, Train Loss: 8.8953, Validation Loss: 6.7168
# Epoch 5/300, Train Loss: 7.2210, Validation Loss: 5.6555
# Epoch 6/300, Train Loss: 6.9486, Validation Loss: 8.1389
# Epoch 7/300, Train Loss: 6.5112, Validation Loss: 4.2881
# Epoch 8/300, Train Loss: 5.7391, Validation Loss: 4.7958
# Epoch 9/300, Train Loss: 5.5621, Validation Loss: 7.0027
# Epoch 10/300, Train Loss: 5.1179, Validation Loss: 4.0894
# Epoch 11/300, Train Loss: 5.1298, Validation Loss: 12.4453
# Epoch 12/300, Train Loss: 4.5654, Validation Loss: 3.5951
# Epoch 13/300, Train Loss: 4.6760, Validation Loss: 3.7381
# Epoch 14/300, Train Loss: 4.9164, Validation Loss: 4.8272
# Epoch 15/300, Train Loss: 5.0142, Validation Loss: 5.9233
# Epoch 16/300, Train Loss: 4.4659, Validation Loss: 5.8500
# Epoch 17/300, Train Loss: 4.4374, Validation Loss: 4.2540
# Epoch 18/300, Train Loss: 4.4456, Validation Loss: 7.3293
# Epoch 19/300, Train Loss: 4.4773, Validation Loss: 4.7886
# Epoch 20/300, Train Loss: 4.7527, Validation Loss: 5.0916
# Epoch 21/300, Train Loss: 4.1286, Validation Loss: 4.2227
# Epoch 22/300, Train Loss: 4.3914, Validation Loss: 4.4128
# Epoch 23/300, Train Loss: 4.2888, Validation Loss: 6.2690
# Epoch 24/300, Train Loss: 4.1042, Validation Loss: 5.4613
# Epoch 25/300, Train Loss: 4.1142, Validation Loss: 5.8023
# Epoch 26/300, Train Loss: 4.4329, Validation Loss: 5.3641
# Epoch 27/300, Train Loss: 4.2144, Validation Loss: 4.3111
# Epoch 28/300, Train Loss: 4.3252, Validation Loss: 3.5244
# Epoch 29/300, Train Loss: 4.1650, Validation Loss: 4.4593
# Epoch 30/300, Train Loss: 4.4813, Validation Loss: 3.3569
# Epoch 31/300, Train Loss: 3.8663, Validation Loss: 4.6775
# Epoch 32/300, Train Loss: 4.1555, Validation Loss: 3.8587
# Epoch 33/300, Train Loss: 3.8858, Validation Loss: 7.5012
# Epoch 34/300, Train Loss: 4.2405, Validation Loss: 5.2577
# Epoch 35/300, Train Loss: 3.8054, Validation Loss: 3.6740
# Epoch 36/300, Train Loss: 3.9276, Validation Loss: 4.7999
# Epoch 37/300, Train Loss: 4.0032, Validation Loss: 3.1975
# Epoch 38/300, Train Loss: 3.8396, Validation Loss: 3.7648
# Epoch 39/300, Train Loss: 3.9229, Validation Loss: 3.2167
# Epoch 40/300, Train Loss: 3.9166, Validation Loss: 3.2962
# Epoch 41/300, Train Loss: 3.9976, Validation Loss: 3.5604
# Epoch 42/300, Train Loss: 3.6267, Validation Loss: 6.1410
# Epoch 43/300, Train Loss: 3.8003, Validation Loss: 3.2761
# Epoch 44/300, Train Loss: 3.7583, Validation Loss: 3.7494
# Epoch 45/300, Train Loss: 3.6859, Validation Loss: 3.3244
# Epoch 46/300, Train Loss: 3.7045, Validation Loss: 5.4324
# Epoch 47/300, Train Loss: 3.5484, Validation Loss: 8.9579
# Epoch 48/300, Train Loss: 3.8737, Validation Loss: 4.2485
# Epoch 49/300, Train Loss: 3.5428, Validation Loss: 3.8582
# Epoch 50/300, Train Loss: 3.6467, Validation Loss: 4.2003
# Epoch 51/300, Train Loss: 3.7216, Validation Loss: 3.2622
# Epoch 52/300, Train Loss: 3.6102, Validation Loss: 5.7421
# Epoch 53/300, Train Loss: 3.6887, Validation Loss: 3.3138
# Epoch 54/300, Train Loss: 3.7435, Validation Loss: 4.4383
# Epoch 55/300, Train Loss: 3.6487, Validation Loss: 3.2161
# Epoch 56/300, Train Loss: 3.6100, Validation Loss: 3.9263
# Epoch 57/300, Train Loss: 3.5043, Validation Loss: 4.3124
# Epoch 58/300, Train Loss: 3.6819, Validation Loss: 4.4596
# Epoch 59/300, Train Loss: 3.5934, Validation Loss: 7.0723
# Epoch 60/300, Train Loss: 3.6407, Validation Loss: 3.3972
# Epoch 61/300, Train Loss: 3.6557, Validation Loss: 3.2023
# Epoch 62/300, Train Loss: 3.4645, Validation Loss: 3.3508
# Epoch 63/300, Train Loss: 3.7402, Validation Loss: 4.3749
# Epoch 64/300, Train Loss: 3.3892, Validation Loss: 4.0059
# Epoch 65/300, Train Loss: 3.5711, Validation Loss: 3.3007
# Epoch 66/300, Train Loss: 3.5475, Validation Loss: 3.3681
# Epoch 67/300, Train Loss: 3.5885, Validation Loss: 3.2226
# Epoch 68/300, Train Loss: 3.5000, Validation Loss: 5.3456
# Epoch 69/300, Train Loss: 3.5388, Validation Loss: 3.7520
# Epoch 70/300, Train Loss: 3.4674, Validation Loss: 3.2506
# Epoch 71/300, Train Loss: 3.4036, Validation Loss: 3.3931
# Epoch 72/300, Train Loss: 3.5862, Validation Loss: 3.2710
# Epoch 73/300, Train Loss: 3.4328, Validation Loss: 3.5527
# Epoch 74/300, Train Loss: 3.7349, Validation Loss: 3.4038
# Epoch 75/300, Train Loss: 3.4050, Validation Loss: 4.4099
# Epoch 76/300, Train Loss: 3.5549, Validation Loss: 3.6056
# Epoch 77/300, Train Loss: 3.5073, Validation Loss: 5.8057
# Epoch 78/300, Train Loss: 3.7453, Validation Loss: 3.2849
# Epoch 79/300, Train Loss: 3.5320, Validation Loss: 6.6382
# Epoch 80/300, Train Loss: 3.4272, Validation Loss: 4.1729
# Epoch 81/300, Train Loss: 3.4005, Validation Loss: 5.2358
# Epoch 82/300, Train Loss: 3.4922, Validation Loss: 3.4003
# Epoch 83/300, Train Loss: 3.4960, Validation Loss: 3.2177
# Epoch 84/300, Train Loss: 3.5710, Validation Loss: 3.4038
# Epoch 85/300, Train Loss: 3.5789, Validation Loss: 3.2286
# Epoch 86/300, Train Loss: 3.4672, Validation Loss: 5.6440
# Epoch 87/300, Train Loss: 3.4354, Validation Loss: 3.4596
# Epoch 88/300, Train Loss: 3.4861, Validation Loss: 3.3816
# Epoch 89/300, Train Loss: 3.3911, Validation Loss: 4.6000
# Epoch 90/300, Train Loss: 3.4049, Validation Loss: 3.2078
# Epoch 91/300, Train Loss: 3.5766, Validation Loss: 3.2152
# Epoch 92/300, Train Loss: 3.3075, Validation Loss: 3.2347
# Epoch 93/300, Train Loss: 3.4428, Validation Loss: 6.4307
# Epoch 94/300, Train Loss: 3.3580, Validation Loss: 3.9951
# Epoch 95/300, Train Loss: 3.4200, Validation Loss: 3.7864
# Epoch 96/300, Train Loss: 3.4422, Validation Loss: 3.9080
# Epoch 97/300, Train Loss: 3.3387, Validation Loss: 3.4439
# Epoch 98/300, Train Loss: 3.2833, Validation Loss: 3.3365
# Epoch 99/300, Train Loss: 3.3340, Validation Loss: 3.4349
# Epoch 100/300, Train Loss: 3.4786, Validation Loss: 3.8293

# %%
import os

X_test_scaled = X_test
X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32)

test_dataset = TensorDataset(X_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=best_batch_size, shuffle=False)


model.eval()
test_pred = []
with torch.no_grad():
    for batch in test_loader:
        batch_X = batch[0].cuda()
        outputs = model(batch_X)
        test_pred.extend(outputs.cpu().numpy())  # 예측값을 CPU로 이동하여 리스트에 추가

test_pred = np.array(test_pred).flatten()
test_pred_original_scale = np.expm1(test_pred)
# 상위 10% 임계값 계산
threshold = np.percentile(test_pred_original_scale, 90)
top_10_percent_mask = test_pred_original_scale >= threshold

# 빈 데이터프레임 생성 (또는 제출 형식에 맞게 생성)
submission_df = pd.read_csv(submission_csv_path)
submission_df['y'] = test_pred_original_scale  # 예측 결과를 y 컬럼에 추가

# 지정된 경로에 CSV 파일로 저장
submission_df.to_csv("/content/drive/MyDrive/new_MLP5.csv", index=False)

# %%
submission_df.describe()
# Out:
#                  y
# count  4986.000000
# mean     83.983414
# std       3.305408
# min      80.719887
# 25%      81.616190
# 50%      82.360104
# 75%      85.363480
# max      91.791939
